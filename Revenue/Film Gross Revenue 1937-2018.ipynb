# %%
import pandas as pd
import numpy
import csv
import matplotlib.pyplot as plt

# %%
disney_films_2016 = pd.read_csv("../Disney_Datasets/disney_movies_total_gross_2016.csv")

disney_films_2018 = pd.read_csv("../Disney_Datasets/disney_movies_total_gross_2018.csv")

disney_films_2016.head()
# Out:
#                        movie_title  release_date      genre MPAA_rating  \
# 0  Snow White and the Seven Dwarfs  Dec 21, 1937    Musical           G
# 1                        Pinocchio   Feb 9, 1940  Adventure           G
# 2                         Fantasia  Nov 13, 1940    Musical           G
# 3                Song of the South  Nov 12, 1946  Adventure           G
# 4                       Cinderella  Feb 15, 1950      Drama           G
#
#     total_gross inflation_adjusted_gross
# 0  $184,925,485           $5,228,953,251
# 1   $84,300,000           $2,188,229,052
# 2   $83,320,000           $2,187,090,808
# 3   $65,000,000           $1,078,510,579
# 4   $85,000,000             $920,608,730

# %%
disney_films_2018.columns
# Out:
# Index(['movie_title', 'Unnamed: 1', 'genre', 'MPAA_rating', 'total_gross',
#        'inflation_adjusted_gross', 'Unnamed: 6'],
#       dtype='object')

# %%
reorganized_df_2016 = disney_films_2016[["movie_title","release_date","total_gross"]]

reorganized_df_2018 = disney_films_2018[["movie_title","Unnamed: 1","total_gross"]]

renamed_df_2018 = reorganized_df_2018.rename(columns={"Unnamed: 1":"release_date"})

renamed_df_2018.head()
# Out:
#                          movie_title release_date    total_gross
# 0  Star Wars Ep. VIII: The Last Jedi    15-Dec-17  $517,218,368
# 1               Beauty and the Beast    17-Mar-17  $504,014,165
# 2      Guardians of the Galaxy Vol 2    05-May-17  $389,813,101
# 3                     Thor: Ragnarok    03-Nov-17  $311,225,150
# 4                               Coco    22-Nov-17  $179,834,199

# %%
merge_table = pd.merge(reorganized_df_2016, renamed_df_2018, on="movie_title", how="outer")

merge_table
# Out:
#                                           movie_title release_date_x  \
# 0                     Snow White and the Seven Dwarfs   Dec 21, 1937
# 1                                           Pinocchio    Feb 9, 1940
# 2                                            Fantasia   Nov 13, 1940
# 3                                   Song of the South   Nov 12, 1946
# 4                                          Cinderella   Feb 15, 1950
# 5                                          Cinderella   Mar 13, 2015
# 6                        20,000 Leagues Under the Sea   Dec 23, 1954
# 7                                  Lady and the Tramp   Jun 22, 1955
# 8                                     Sleeping Beauty   Jan 29, 1959
# 9                                      101 Dalmatians   Jan 25, 1961
# 10                                     101 Dalmatians   Nov 27, 1996
# 11                        The Absent Minded Professor   Mar 16, 1961
# 12                                   Babes in Toyland   Dec 14, 1961
# ...
